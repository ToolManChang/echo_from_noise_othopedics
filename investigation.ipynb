# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
annotation_img = cv2.imread('/home/yunkao/git/echo_from_noise/data_preparation/CAMUS_augmented_data/2CH_ED_augmented/sector_annotations/training/patient0001_2CH_ED_train_3.png')
print(np.unique(annotation_img))
# Out:
# [0 1 2 3 4]

# %%
plt.imshow(annotation_img * 50)
plt.show()
